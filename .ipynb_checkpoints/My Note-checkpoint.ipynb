# %% [markdown]
# # Control backslash to comment or uncomment.

# %% [markdown]
# # We cannot use special symbols like `!,@,#,$,%`etc.in our identifier.

# %% [markdown]
# # Multi-line comment.

# %%
print("Hello everyone My name is Aayus gc.\nI live in Baneshwor height\nAnd am currently taking python training classes.")
# Out:
# Hello everyone My name is Aayus gc.
# I live in Baneshwor height
# And am currently taking python training classes.

# %% [markdown]
# # Escape sequence character

# %% [markdown]
# Is a backslash \ followed by the character you want to insert.

# %%
print("Hey I am a "\good boy\"!!")

# %%
first_sentence = "Hey this is an all out error"

# %%
first_sentence

# %%
#hi everyone @comment

# %%
x = 23
print(x)
print("the type of x is ",type(x))

# %%
x = 28
print(x)
y = "harry"
print(y)
z = complex(8 ,2)
print(z)
print("the type of x is ",type(x))
print("the type of y is ",type(y))
print("the type of z is ",type(z))
# Out:
# 28
# harry
# (8+2j)
# the type of x is  <class 'int'>
# the type of y is  <class 'str'>
# the type of z is  <class 'complex'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 4
if (a>5):
    print("the value of a is greater than 9")
else:
    print("the vlaue of a is less than 9")
# Out:
# the vlaue of a is less than 9

# %%
list1 =[2,4.8,[4, -5], ["apple", "bannana"]]
print(list1)
# Out:
# [2, 4.8, [4, -5], ['apple', 'bannana']]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
tuple2 = (("parrot ", "carrot", "darrot",("lion, wolf")))
print(tuple2)
# Out:
# ('parrot ', 'carrot', 'darrot', 'lion, wolf')

# %%
 a = 5
 b = 6
print("the value of ",a," + ",b,"is ",a + b)
print("the value of ",a," - ",b,"is ",a - b)
print("the value of ",a," * ",b,"is ",a * b)
print("the value of ",a," / ",b,"is ",a / b)

# %% [markdown]
# # Interactive devolpment environment(IDE).

# %%
km =int(input("enter the value in km"))
meter = km*1000
print(km,"the value in meter is",meter,"meter")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #volume of sphere
# $volume(v) = \frac{4}{3} \pi r^3$

# %%
import math
PI = math.pi
radius = float(input("enter the radius: "))
volume = 4/3 *PI * radius ** 3
print(f"the value of sphere is {round(radius,2)}.")
# Out:
# enter the radius: 5
# the value of sphere is 5.0.

# %% [markdown]
# # operator procedence.

# %%
#equivalent to
2*9
# Out:
# 18

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
# Out:
# 81

# %% [markdown]
# # Equivalent: right to left -- exponention opertaor ko lagi matra other left to right.

# %% [markdown]
# assignment

# %%
age = int(input("enter the age: "))
if (age>=18):
    print("the person is alligible ")
else:
    print("the person is not alligible")
# Out:
# enter the age: 17
# the person is not alligible

# %%
str1 =("he is an honest man")#.find
print(str1.find("nest man"))
# Out:
# 11
